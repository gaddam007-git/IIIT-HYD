# %% [markdown]
# <a href="https://colab.research.google.com/github/gaddam007-git/IIIT-HYD/blob/main/PROJECTS/Copy_of_AIML_Module_5_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 5 Project: Regression analysis on a COVID-dataset

# %% [markdown]
# In this project, we will use the concepts of regression and regularization we have learnt to predict early Covid-19 cases. We shall use linear regression, polynomial regression and ridge regression to obtain a reasonably good estimate of the future cases. Try experimenting with hyperparameters to obtain better results.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### 1. **Load the data** into a pandas dataframe.

# %%
# Imports
import pandas as pd
import numpy  as np
import scipy.integrate

from matplotlib import pyplot as plt
plt.style.use('ggplot')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 8

import copy
from   sklearn.metrics       import mean_squared_error, mean_absolute_error
from   sklearn.linear_model  import LinearRegression, BayesianRidge
from   sklearn.tree          import DecisionTreeRegressor
from   sklearn.preprocessing import PolynomialFeatures

# %%
path = "https://raw.githubusercontent.com/PranavTadimeti/Regression_Project/main/covid_19_data.csv"
df_orig = pd.read_csv(path)
print(df_orig)
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 10666  10667      03/31/2020        Wyoming              US
# 10667  10668      03/31/2020       Xinjiang  Mainland China
# 10668  10669      03/31/2020          Yukon          Canada
# 10669  10670      03/31/2020         Yunnan  Mainland China
# 10670  10671      03/31/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# 3          1/22/2020 17:00        1.0     0.0        0.0
# 4          1/22/2020 17:00        0.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 10666  2020-03-31 23:49:27      109.0     0.0        0.0
# 10667  2020-03-31 23:49:27       76.0     3.0       73.0
# 10668  2020-03-31 23:49:27        5.0     0.0        0.0
# 10669  2020-03-31 23:49:27      182.0     2.0      172.0
# 10670  2020-03-31 23:49:27     1257.0     1.0     1226.0
#
# [10671 rows x 8 columns]

# %% [markdown]
# ### 2. Create a new dataframe which counts the cumulative total number of cases, the cumulative total number of deaths, and also  cumulative total number of recoveries for each date.

# %%
df = copy.deepcopy(df_orig)
df.drop('Last Update',inplace=True,axis=1)
date_lst  = df.ObservationDate.unique()
date_dict = {}

for i in range(len(date_lst)):
    df_temp = df.loc[df['ObservationDate'] == date_lst[i]]
    date_dict[date_lst[i]] = df_temp

# %%
date_tot_tup_dict = {};
for date, df in date_dict.items():
    tup_temp = (df['Confirmed'].sum(), df['Deaths'].sum(), df['Recovered'].sum())
    date_tot_tup_dict[date] = tup_temp

# %%
print(date_tot_tup_dict)
# Out:
# {'01/22/2020': (np.float64(555.0), np.float64(17.0), np.float64(28.0)), '01/23/2020': (np.float64(653.0), np.float64(18.0), np.float64(30.0)), '01/24/2020': (np.float64(941.0), np.float64(26.0), np.float64(36.0)), '01/25/2020': (np.float64(1438.0), np.float64(42.0), np.float64(39.0)), '01/26/2020': (np.float64(2118.0), np.float64(56.0), np.float64(52.0)), '01/27/2020': (np.float64(2927.0), np.float64(82.0), np.float64(61.0)), '01/28/2020': (np.float64(5578.0), np.float64(131.0), np.float64(107.0)), '01/29/2020': (np.float64(6165.0), np.float64(133.0), np.float64(126.0)), '01/30/2020': (np.float64(8235.0), np.float64(171.0), np.float64(143.0)), '01/31/2020': (np.float64(9925.0), np.float64(213.0), np.float64(222.0)), '02/01/2020': (np.float64(12038.0), np.float64(259.0), np.float64(284.0)), '02/02/2020': (np.float64(16787.0), np.float64(362.0), np.float64(472.0)), '02/03/2020': (np.float64(19881.0), np.float64(426.0), np.float64(623.0)), '02/04/2020': (np.float64(23892.0), np.float64(492.0), np.float64(852.0)), '02/05/2020': (np.float64(27636.0), np.float64(564.0), np.float64(1124.0)), '02/06/2020': (np.float64(30818.0), np.float64(634.0), np.float64(1487.0)), '02/07/2020': (np.float64(34392.0), np.float64(719.0), np.float64(2011.0)), '02/08/2020': (np.float64(37121.0), np.float64(806.0), np.float64(2616.0)), '02/09/2020': (np.float64(40151.0), np.float64(906.0), np.float64(3244.0)), '02/10/2020': (np.float64(42763.0), np.float64(1013.0), np.float64(3946.0)), '02/11/2020': (np.float64(44803.0), np.float64(1113.0), np.float64(4683.0)), '02/12/2020': (np.float64(45222.0), np.float64(1118.0), np.float64(5150.0)), '02/13/2020': (np.float64(60370.0), np.float64(1371.0), np.float64(6295.0)), '02/14/2020': (np.float64(66887.0), np.float64(1523.0), np.float64(8058.0)), '02/15/2020': (np.float64(69032.0), np.float64(1666.0), np.float64(9395.0)), '02/16/2020': (np.float64(71226.0), np.float64(1770.0), np.float64(10865.0)), '02/17/2020': (np.float64(73260.0), np.float64(1868.0), np.float64(12583.0)), '02/18/2020': (np.float64(75138.0), np.float64(2007.0), np.float64(14352.0)), '02/19/2020': (np.float64(75641.0), np.float64(2122.0), np.float64(16121.0)), '02/20/2020': (np.float64(76199.0), np.float64(2247.0), np.float64(18177.0)), '02/21/2020': (np.float64(76843.0), np.float64(2251.0), np.float64(18890.0)), '02/22/2020': (np.float64(78599.0), np.float64(2458.0), np.float64(22886.0)), '02/23/2020': (np.float64(78985.0), np.float64(2469.0), np.float64(23394.0)), '02/24/2020': (np.float64(79570.0), np.float64(2629.0), np.float64(25227.0)), '02/25/2020': (np.float64(80415.0), np.float64(2708.0), np.float64(27905.0)), '02/26/2020': (np.float64(81397.0), np.float64(2770.0), np.float64(30384.0)), '02/27/2020': (np.float64(82756.0), np.float64(2814.0), np.float64(33277.0)), '02/28/2020': (np.float64(84124.0), np.float64(2872.0), np.float64(36711.0)), '02/29/2020': (np.float64(86013.0), np.float64(2941.0), np.float64(39782.0)), '03/01/2020': (np.float64(88371.0), np.float64(2996.0), np.float64(42716.0)), '03/02/2020': (np.float64(90309.0), np.float64(3085.0), np.float64(45602.0)), '03/03/2020': (np.float64(92844.0), np.float64(3160.0), np.float64(48229.0)), '03/04/2020': (np.float64(95124.0), np.float64(3254.0), np.float64(51171.0)), '03/05/2020': (np.float64(97886.0), np.float64(3348.0), np.float64(53797.0)), '03/06/2020': (np.float64(101800.0), np.float64(3460.0), np.float64(55866.0)), '03/07/2020': (np.float64(105836.0), np.float64(3558.0), np.float64(58359.0)), '03/08/2020': (np.float64(109835.0), np.float64(3803.0), np.float64(60695.0)), '03/09/2020': (np.float64(113582.0), np.float64(3996.0), np.float64(62512.0)), '03/10/2020': (np.float64(118582.0), np.float64(4262.0), np.float64(64404.0)), '03/11/2020': (np.float64(125865.0), np.float64(4615.0), np.float64(67003.0)), '03/12/2020': (np.float64(128343.0), np.float64(4720.0), np.float64(68324.0)), '03/13/2020': (np.float64(145193.0), np.float64(5404.0), np.float64(70251.0)), '03/14/2020': (np. ...

# %%
df_date_tots = pd.DataFrame(date_tot_tup_dict)
df_date_tots = df_date_tots.transpose()
df_date_tots.columns = ['Confirmed', 'Deaths', 'Recovered']
print(df_date_tots.head())
# Out:
#             Confirmed  Deaths  Recovered
# 01/22/2020      555.0    17.0       28.0
# 01/23/2020      653.0    18.0       30.0
# 01/24/2020      941.0    26.0       36.0
# 01/25/2020     1438.0    42.0       39.0
# 01/26/2020     2118.0    56.0       52.0

# %% [markdown]
# ### 3. Create a new column in the dataframe called **“closed cases”**

# %%
df_date_tots['Closed Cases'] = df_date_tots['Deaths'] + df_date_tots['Recovered']

# %% [markdown]
# ### 4. Create a new column in the dataframe called “active cases”

# %%
df_date_tots['Active Cases'] = df_date_tots['Confirmed'] - df_date_tots['Closed Cases']

# %% [markdown]
# ### 5. **Plot** the total number of cases per day over time and summarize findings

# %%
plt.figure(figsize = [15,5])
plt.plot(df_date_tots['Confirmed'], label = "Confirmed Cases")
plt.plot(df_date_tots['Deaths'], label    = "Deaths")
plt.plot(df_date_tots['Recovered'], label = "Recovered Cases")

plt.legend()
plt.xlabel("Day")
plt.ylabel("Count")
plt.xticks(rotation = 90);
start_date = str(date_lst[0]);
fin_date   = str(date_lst[len(date_lst) -1])
plt.title("Total Cases, Deaths, and Recoveries : " + start_date + " - " + fin_date);

# %% [markdown]
# All of the three curves seem to be exponential (start of logistic curve). The confirmed cases was obviously higher than the deaths and recovered cases. The rate of the the recovered cases seems to be higher than that of the death curve.

# %% [markdown]
# ### 6. Create one **plot** showing the trend of number of active cases and closed cases

# %%
plt.figure(figsize = [15,5])
plt.plot(df_date_tots['Active Cases'], label = "Active Cases")
plt.plot(df_date_tots['Closed Cases'], label = "Closed Cases")

plt.legend();
plt.xlabel("Day")
plt.ylabel("Count")
plt.xticks(rotation = 90)
start_date = str(date_lst[0])
fin_date   = str(date_lst[len(date_lst) -1])
plt.title("Active Cases vs Closed Cases COVID-19 : " + start_date + " - " + fin_date);

# %% [markdown]
# The number of active cases is higher than the number of closed cases as of yet.

# %% [markdown]
# ### 7. Growth Factor

# %% [markdown]
# **Growth factor** is the factor by which a quantity multiplies itself over time. In the below cell, we calculate the GF of the confirmed, recovered and death cases.

# %%
growth_len_lst = len(date_lst) - 1
confirmed_lst = df_date_tots["Confirmed"]
death_lst = df_date_tots["Deaths"]
recovered_lst = df_date_tots["Recovered"]
confGF_lst = []
deathsGF_lst = []
recovGF_lst = []
for i in range(growth_len_lst):
    confirmedGF = confirmed_lst[i+1] / confirmed_lst[i]
    confGF_lst.append(confirmedGF)
    deathGF = death_lst[i+1] / death_lst[i]
    deathsGF_lst.append(deathGF)
    recoveredGF = recovered_lst[i+1] / recovered_lst[i]
    recovGF_lst.append(recoveredGF);
# Out:
# /tmp/ipykernel_1971/3700421734.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   confirmedGF = confirmed_lst[i+1] / confirmed_lst[i]
# /tmp/ipykernel_1971/3700421734.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   deathGF = death_lst[i+1] / death_lst[i]
# /tmp/ipykernel_1971/3700421734.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   recoveredGF = recovered_lst[i+1] / recovered_lst[i]

# %% [markdown]
# ### 8. Create one plot showing the Growth factor of confirmed, recovered and death cases wrt days

# %%
plt.figure(figsize = [15,5])
plt.plot(confGF_lst, label = "Growth Factor of Confirmed Cases")
plt.plot(deathsGF_lst, label = "Growth Factor of Deaths")
plt.plot(recovGF_lst, label = "Growth Factor of Recovered Cases")
x = []
for i in range((growth_len_lst)):
    x.append(1)
plt.plot(x, label = "Growth Factor = 1.0")

#plt.grid()
plt.legend()
plt.xlabel("Day")
plt.ylabel("Growth Ratio")
plt.ylim(.5,2)
plt.xticks(rotation = 90)
start_date = str(date_lst[0])
fin_date   = str(date_lst[len(date_lst) -1])
plt.title("Growth Factors of Confirmed, Death, and Recovered Cases COVID-19 : " +start_date +" - " +fin_date)
# Out:
# Text(0.5, 1.0, 'Growth Factors of Confirmed, Death, and Recovered Cases COVID-19 : 01/22/2020 - 03/31/2020')

# %% [markdown]
# # **Part 2 - Prediction Using Linear Regression**

# %% [markdown]
# #### To make our data to be compatible with *sklearn* format, create a new column called “Days since” which tracks the number of days since the initial date.

# %%
days_since_lst = []
for i in range(len(date_lst)):
    days_since_lst.append(i)
df_date_tots["Days Since:"] = days_since_lst
df_date_tots = df_date_tots[["Days Since:", "Confirmed", "Deaths", "Recovered", "Active Cases", "Closed Cases"]]

# %% [markdown]
# ### 8. Take the earliest 85% of the dates as **train** and the rest as **test**

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

X = np.array(df_date_tots["Days Since:"]).reshape(-1,1)
y = np.array(df_date_tots["Confirmed"])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = 0.15,
                                                    shuffle = False)

# %% [markdown]
# ### 9. We can try different regression and regularizations we have seen before

# %% [markdown]
# #### 9.1 Linear Regression

# %%
lin_model = LinearRegression(fit_intercept = False)
lin_model.fit(X_train, y_train)
test_lin_pred = lin_model.predict(X_test)
lin_pred = lin_model.predict(X)

# %%
plt.figure(figsize=(15,5))

# Actual values
plt.plot(X_test,
         y_test,
         label="Actual Confirmed Cases")

# Predicted values
plt.plot(X_test,
         test_lin_pred,
         label="Linear Regression Predicted Confirmed Cases")

plt.grid()
plt.legend()
plt.xlabel("Day", size=25)
plt.ylabel("Count", size=25)
plt.xticks(rotation=90, size=15)
plt.show()

# Correct error calculations
print("MAE:", mean_absolute_error(y_test, test_lin_pred))
print("MSE:", mean_squared_error(y_test, test_lin_pred))
# Out:
# MAE: 368049.30417332525
# MSE: 164288029427.18597

# %% [markdown]
# #### Polynomial Regression

# %%
poly = PolynomialFeatures(degree=5)
poly_X_train = poly.fit_transform(X_train)
poly_X_test  = poly.fit_transform(X_test)
poly_X = poly.fit_transform(X)

# %%
linear_model = LinearRegression(fit_intercept=False)
linear_model.fit(poly_X_train, y_train)
test_poly_pred = linear_model.predict(poly_X_test)
poly_pred = linear_model.predict(poly_X)

# %%
plt.figure(figsize=[15,5])

# Actual values
plt.plot(X_test,
         y_test,
         label="Actual Confirmed Cases")

# Predicted values
plt.plot(X_test,
         test_poly_pred,
         label="Polynomial Regression Confirmed Cases")

plt.grid()
plt.legend()
plt.xlabel("Day", size=25)
plt.ylabel("Count", size=25)
plt.xticks(rotation=90, size=15)
plt.show()

# Error Metrics
print("MAE:", mean_absolute_error(y_test, test_poly_pred))
print("MSE:", mean_squared_error(y_test, test_poly_pred))
# Out:
# MAE: 31989.752428427022
# MSE: 1314905574.5277777

# %%
plt.figure(figsize=(15, 5))
plt.plot(X,
         y,
         label = 'Actual Future Cases')

plt.plot(X,
         poly_pred,
         label = 'Polynomial Regression Prediction of Future Cases',
         linestyle = "dashed")

plt.plot(X_train,
         y_train,
         label = 'Training Cases')

plt.xlabel('Days Since', size = 30)
plt.ylabel('# of Cases', size = 30)
plt.legend()
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# ### 9.2 Ridge Regression

# %%
tol      = [1e-4, 1e-3, 1e-2]
alpha_1  = [1e-7, 1e-6, 1e-5, 1e-4]
alpha_2  = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_1 = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_2 = [1e-7, 1e-6, 1e-5, 1e-4]

bayesian_grid = {'tol': tol,
                 'alpha_1': alpha_1,
                 'alpha_2' : alpha_2,
                 'lambda_1': lambda_1,
                 'lambda_2' : lambda_2 }

bayesian = BayesianRidge(fit_intercept=False)
bayesian_search = RandomizedSearchCV(bayesian,
                                     bayesian_grid,
                                     scoring='neg_mean_squared_error',
                                     cv=3,
                                     return_train_score=True,
                                     n_jobs=-1,
                                     n_iter=40,
                                     verbose=1)

bayesian_search.fit(X_train, y_train)

print(bayesian_search.best_params_)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# {'tol': 0.01, 'lambda_2': 1e-05, 'lambda_1': 0.0001, 'alpha_2': 1e-05, 'alpha_1': 1e-07}

# %%
y_test_ridge_pred = bayesian_search.predict(X_test);
y_ridge_pred = bayesian_search.predict(X);

# %%
plt.figure(figsize=[15,5])

# Actual values
plt.plot(X_test,
         y_test,
         label="Actual Confirmed Cases")

# Predicted values
plt.plot(X_test,
         y_test_ridge_pred,
         label="Bayesian Ridge Predicted Confirmed Cases")

plt.grid()
plt.legend()
plt.xlabel("Day", size=25)
plt.ylabel("Count", size=25)
plt.xticks(rotation=90, size=15)
plt.show()

# Correct Error Metrics
print("MAE:", mean_absolute_error(y_test, y_test_ridge_pred))
print("MSE:", mean_squared_error(y_test, y_test_ridge_pred))
# Out:
# MAE: 368251.9660658479
# MSE: 164440629513.75995

# %%
plt.figure(figsize=(15, 5))
plt.plot(X,
         y,
         label = 'Actual Future Cases')
plt.plot(X,
         y_ridge_pred,
         label = 'Ridge Prediction of Future Cases',
         linestyle = "dashed")
plt.plot(X_train,
         y_train,
         label = 'Training Cases')

#plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since', size = 30)
plt.ylabel('# of Cases', size = 30)
plt.legend()
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# #### Polynomial Ridge Regression

# %%
bayesian_search_poly = RandomizedSearchCV(bayesian,
                                     bayesian_grid,
                                     scoring='neg_mean_squared_error',
                                     cv=3,
                                     return_train_score=True,
                                     n_jobs=-1,
                                     n_iter=40,
                                     verbose=1)

# %%
bayesian_search_poly.fit(poly_X_train, y_train);
print(bayesian_search_poly.best_params_)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# {'tol': 0.0001, 'lambda_2': 0.0001, 'lambda_1': 0.0001, 'alpha_2': 1e-06, 'alpha_1': 1e-06}

# %%
bayesian_poly_confirmed = bayesian_search_poly.best_estimator_
test_poly_bayesian_pred = bayesian_poly_confirmed.predict(poly_X_test)
bayesian_poly_pred = bayesian_poly_confirmed.predict(poly_X)

# %%
plt.figure(figsize=[15,5])

# Actual values
plt.plot(X_test,
         y_test,
         label="Actual Confirmed Cases")

# Predicted values
plt.plot(X_test,
         test_poly_bayesian_pred,
         label="Polynomial Bayesian Ridge Predicted Confirmed Cases")

plt.grid()
plt.legend()
plt.xlabel("Day", size=25)
plt.ylabel("Count", size=25)
plt.xticks(rotation=90, size=15)
plt.show()

print("MAE:", mean_absolute_error(y_test, test_poly_bayesian_pred))
print("MSE:", mean_squared_error(y_test, test_poly_bayesian_pred))
# Out:
# MAE: 15796.104528795357
# MSE: 352565821.2188473

# %%
plt.figure(figsize=(15, 5))
plt.plot(X,
         y,
         label = 'Actual Future Cases')
plt.plot(X,
         bayesian_poly_pred,
         label = 'Ridge Polynomial Prediction of Future Cases',
         linestyle = "dashed")
plt.plot(X_train,
         y_train,
         label = 'Training Cases')

#plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since', size = 30)
plt.ylabel('# of Cases', size = 30)
#plt.grid()
plt.legend()
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
print("Polynomial Regression")
print('\tMAE:', mean_absolute_error(y_test, test_poly_pred))
print('\tMSE:', mean_squared_error(y_test, test_poly_pred))

print("\nRidge Polynomial Regression")
print('\tMAE:', mean_absolute_error(y_test, test_poly_bayesian_pred))
print('\tMSE:', mean_squared_error(y_test, test_poly_bayesian_pred))
# Out:
# Polynomial Regression
# 	MAE: 31989.752428427022
# 	MSE: 1314905574.5277777
#
# Ridge Polynomial Regression
# 	MAE: 15796.104528795357
# 	MSE: 352565821.2188473

# %% [markdown]
# From Mean Absolute Error and Mean Squared Error values, Ridge Polynomial Regression Model seems to be the best model.
